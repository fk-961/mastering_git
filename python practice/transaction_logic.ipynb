# %% [markdown]
# # Transaction logic

# %%
transactions = [
    {"amount" : 50, "category" : "food"},
    {"amount" : 120, "category" : "transport"},
    {"amount" : 80, "category" : "food"},
]

# %% [markdown]
# ## Useful functions:
# - total spending
# - get transactions of a specific category
# - get the biggest transaction
# - get the spending by each category

# %%
def total_spending(transactions : list) -> float:
    total = 0
    for transaction in transactions:
        total += transaction["amount"]
    return total

def get_categories(transactions : list) -> list:
    categories = set()
    for transaction in transactions:
        categories.add(transaction["category"])
    return sorted(list(categories))

def filter_category(
    transactions : list,
    category : str
) -> list:
    if category not in get_categories(transactions):
        raise ValueError("Category not found !")
    else:
        matching_transactions = []
        for transaction in transactions:
            if transaction["category"] == category:
                matching_transactions.append(transaction)
        return matching_transactions
    
def biggest_transaction(transactions : list) -> float:
    amounts = []
    for transaction in transactions:
        amounts.append(transaction["amount"])
    return max(amounts)

def spending_by_category(transactions):
    spending = {}
    for transaction in transactions:
        if transaction["category"] in spending:
            spending[transaction["category"]] += transaction["amount"]
        else:
            spending[transaction["category"]] = transaction["amount"]
    return spending

# %%
filter_category(transactions, "waww")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 filter_category(transactions, "waww")
#
# Cell In[18], line 18, in filter_category(transactions, category)
#      13 def filter_category(
#      14     transactions : list,
#      15     category : str
#      16 ) -> list:
#      17     if category not in get_categories(transactions):
# ---> 18         raise ValueError("Category not found !")
#      19     else:
#      20         matching_transactions = []
#
# ValueError: Category not found !
