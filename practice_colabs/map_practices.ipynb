# %%
from typing import List

# %% [markdown]
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
#
#
# Example 1:
#
# Input: nums = [2,7,11,15], target = 9
# Output: [0,1]
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
#
# Example 2:
#
# Input: nums = [3,2,4], target = 6
# Output: [1,2]
#
# Example 3:
#
# Input: nums = [3,3], target = 6
# Output: [0,1]
#
#
# Follow-up: Can you come up with an algorithm that is less than O(n2) time complexity?

# %%
def two_sum(nums: List[int], target: int) -> List[int]:
    """The idea here is to use a map that we build while iterating through
    the nums list. If we find the solution we return it since we know that
    there is only one solution to the problem.
    
    This way we reduce the time complexity to O(n) instead of O(n2) but the
    space complexity is increased (and we don't really mind)
    """
    hashmap = {}
    for i in range(len(nums)):
        x = target - nums[i]
        if x in hashmap:
            return([i,hashmap[x]])
        hashmap[nums[i]] = i
        
    return None

# %%
print("wawa")
# Out:
# wawa

# %%
two_sum(
    [2,7,11,15], 9
)
# Out:
# [1, 0]
